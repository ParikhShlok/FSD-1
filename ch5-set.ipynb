# %%
#empty set
s=set()
print(s)
print(type(s))
# Out:
# set()
# <class 'set'>

# %%
s={5,4,6,85,2,2,9,25,8,3,9,39,0}
print(len(s))
print(s)
# Out:
# 11
# {0, 2, 3, 4, 5, 6, 39, 8, 9, 85, 25}

# %%
l=[0, 2, 3, 4, 5, 6, 39, 8, 9, 85, 25]
print(type(l))
x=set(l)
print(set(l))
print(type(x))
print(type(l))#km k te ani original type j kese
# Out:
# <class 'list'>
# {0, 2, 3, 4, 5, 6, 39, 8, 9, 85, 25}
# <class 'set'>
# <class 'list'>

# %%
#mathematical operator
s={0, 2, 3, 4}
s1={0,2,4,58,59,12,2}
print(s.intersection(s1))
# Out:
# {0, 2, 4}

# %%
print(s.union(s1))
# Out:
# {0, 2, 3, 4, 12, 58, 59}

# %%
print(s1.difference(s))
# Out:
# {58, 59, 12}

# %%
print(s.difference(s1))
# Out:
# {3}
