# %%
import pandas as pd
import numpy as np
data={
    "Name":["A",'B','A',"D"],
    "City":["Ahemadabad",'surat',"Ahemadabad",'rajkot'],
    "Age":[20,21,20,30]
    
}
df=pd.DataFrame(data)
df
# Out:
#   Name        City  Age
# 0    A  Ahemadabad   20
# 1    B       surat   21
# 2    A  Ahemadabad   20
# 3    D      rajkot   30

# %%
df.drop_duplicates(keep=False,inplace=True)
df
# Out:
#   Name    City  Age
# 1    B   surat   21
# 3    D  rajkot   30

# %%
df.sort_values(by='City',ascending=True)
# Out:
#   Name        City  Age
# 0    A  Ahemadabad   20
# 2    A  Ahemadabad   20
# 3    D      rajkot   30
# 1    B       surat   21

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
df.sum(axis=1)
# Out:
# 0    20.0
# 1    21.0
# 2     0.0
# 3     0.0
# dtype: float64

# %%
df.duplicated(subset=['Name','City'])
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
import pandas as pd
import numpy as np
data={
    "Name":["Pranav","Meet","Rutu","Neelkanth","Riya","Kalpesh"],
    "Age":[17,18,17,18,17,18],
    "City":["Ahemadabad","Surat","Rajkot","Ahemadabad","Anand","Iamnagar"],
    "Salary":[1000,2000,3000,4000,5000,6000]
}
df=pd.DataFrame(data)
df

# %%
df.loc[1]

# %%
import pandas as pd
import numpy as np
data={
    "A":[1,2,4,7],
    "B":[8,9,np.nan,10],
    "C":[np.nan,13,14,15],
    "D":[20,np.nan,33,45]
}
df=pd.DataFrame(data)
df
# Out:
#    A     B     C     D
# 0  1   8.0   NaN  20.0
# 1  2   9.0  13.0   NaN
# 2  4   NaN  14.0  33.0
# 3  7  10.0  15.0  45.0

# %%
df.set_index('A',drop=True,inplace=True)
df
# Out:
#       B     C     D
# A
# 1   8.0   NaN  20.0
# 2   9.0  13.0   NaN
# 4   NaN  14.0  33.0
# 7  10.0  15.0  45.0

# %%
df.reset_index()
# Out:
#    A     B     C     D
# 0  1   8.0   NaN  20.0
# 1  2   9.0  13.0   NaN
# 2  4   NaN  14.0  33.0
# 3  7  10.0  15.0  45.0

# %%
df.loc[1,"A"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'A'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-d595c985c811> in <module>
# ----> 1 df.loc[1,"A"]
#
# ...

# %%
df.iloc[1,2]
# Out:
# nan

# %%
df['E']=['Ahem','rajkot','lalanagar','navarangpura']
df
# Out:
#    A     B     C     D             E
# 0  1   8.0   NaN  20.0          Ahem
# 1  2   9.0  13.0   NaN        rajkot
# 2  4   NaN  14.0  33.0     lalanagar
# 3  7  10.0  15.0  45.0  navarangpura

# %%
df.loc[4]=[7,10,15,45,'Ahem']
df
# Out:
#    A     B     C     D             E
# 0  1   8.0   NaN  20.0          Ahem
# 1  2   9.0  13.0   NaN        rajkot
# 2  4   NaN  14.0  33.0     lalanagar
# 3  7  10.0  15.0  45.0  navarangpura
# 4  7  10.0  15.0  45.0          Ahem

# %%
import pandas as pd
import numpy as np
data={
    "Name":["A","B","C","D"],
    "Age":[20,21,10,30],
    "City":["Delhi","Mumbai","Ahemadabad","Surat"]
    
    
}
df=pd.DataFrame(data,index=[3,2,0,9])
df
# Out:
#   Name  Age        City
# 3    A   20       Delhi
# 2    B   21      Mumbai
# 0    C   10  Ahemadabad
# 9    D   30       Surat

# %%
df.sort_index(ascending=False)
# Out:
#   Name  Age        City
# 9    D   30       Surat
# 3    A   20       Delhi
# 2    B   21      Mumbai
# 0    C   10  Ahemadabad

# %%
df.sort_index(ascending=True)
# Out:
#   Name  Age        City
# 0    C   10  Ahemadabad
# 2    B   21      Mumbai
# 3    A   20       Delhi
# 9    D   30       Surat

# %%
import pandas as pd
import numpy as np
data={
    "Name":["A","B","C","D","E","F","G","H"],
    "Gender":["Male","Femal","Male","Femal","Male","Femal","Male","Femal"],
    "Dept":["IT","HR","IT","Finance","HR","IT","Finance","hr"],
    "Math":[80,90,75,85,100,90,60,70],
    "Sci":[70,80,90,100,85,75,65,85],
    "Eng":[80,90,100,110,20,45,75,85],
    "Attendnce":[60,70,80,90,85,95,65,75]
}
df=pd.DataFrame(data)
df
# Out:
#   Name Gender     Dept  Math  Sci  Eng  Attendnce
# 0    A   Male       IT    80   70   80         60
# 1    B  Femal       HR    90   80   90         70
# 2    C   Male       IT    75   90  100         80
# 3    D  Femal  Finance    85  100  110         90
# 4    E   Male       HR   100   85   20         85
# 5    F  Femal       IT    90   75   45         95
# 6    G   Male  Finance    60   65   75         65
# 7    H  Femal       hr    70   85   85         75

# %%
df.mean()
# Out:
# Math         81.250
# Sci          81.250
# Eng          75.625
# Attendnce    77.500
# dtype: float64

# %%
df.mean(axis=0)
# Out:
# Math         81.250
# Sci          81.250
# Eng          75.625
# Attendnce    77.500
# dtype: float64

# %%
df.mean(numeric_only=True)
# Out:
# Math         81.250
# Sci          81.250
# Eng          75.625
# Attendnce    77.500
# dtype: float64

# %%
df.sum()
# Out:
# Name                                     ABCDEFGH
# Gender       MaleFemalMaleFemalMaleFemalMaleFemal
# Dept                   ITHRITFinanceHRITFinancehr
# Math                                          650
# Sci                                           650
# Eng                                           605
# Attendnce                                     620
# dtype: object

# %%
df.sum(axis=0)
# Out:
# Name                                     ABCDEFGH
# Gender       MaleFemalMaleFemalMaleFemalMaleFemal
# Dept                   ITHRITFinanceHRITFinancehr
# Math                                          650
# Sci                                           650
# Eng                                           605
# Attendnce                                     620
# dtype: object

# %%
df.sum(numeric_only=True)
# Out:
# Math         650
# Sci          650
# Eng          605
# Attendnce    620
# dtype: int64

# %%
df.sum(axis=1)
# Out:
# 0    290
# 1    330
# 2    345
# 3    385
# 4    290
# 5    305
# 6    265
# 7    315
# dtype: int64

# %%
df['Sci'].mean()
# Out:
# 81.25

# %%
df['Sci'].sum()
# Out:
# 650

# %%
df['Math'].sum()
# Out:
# 650

# %%
df['Eng'].sum()
# Out:
# 605

# %%
df['Attendnce'].sum()
# Out:
# 620

# %%
df.max()
# Out:
# Name            H
# Gender       Male
# Dept           hr
# Math          100
# Sci           100
# Eng           110
# Attendnce      95
# dtype: object

# %%
df['Eng'].max()
# Out:
# 110

# %%
df.median()
# Out:
# Math         82.5
# Sci          82.5
# Eng          82.5
# Attendnce    77.5
# dtype: float64

# %%
df.mode()
# Out:
#   Name Gender Dept  Math   Sci  Eng  Attendnce
# 0    A  Femal   IT  90.0  85.0   20         60
# 1    B   Male  NaN   NaN   NaN   45         65
# 2    C    NaN  NaN   NaN   NaN   75         70
# 3    D    NaN  NaN   NaN   NaN   80         75
# 4    E    NaN  NaN   NaN   NaN   85         80
# 5    F    NaN  NaN   NaN   NaN   90         85
# 6    G    NaN  NaN   NaN   NaN  100         90
# 7    H    NaN  NaN   NaN   NaN  110         95

# %%
df['Eng'].mode()
# Out:
# 0     20
# 1     45
# 2     75
# 3     80
# 4     85
# 5     90
# 6    100
# 7    110
# dtype: int64

# %%
df.corr()
# Out:
#                Math       Sci       Eng  Attendnce
# Math       1.000000  0.335903 -0.495004   0.526135
# Sci        0.335903  1.000000  0.351257   0.595647
# Eng       -0.495004  0.351257  1.000000  -0.261306
# Attendnce  0.526135  0.595647 -0.261306   1.000000

# %%
df['Math'].quantile(0.25)
# Out:
# 73.75

# %%
df['Eng'].quantile(0.25)
# Out:
# 67.5

# %%
df['Sci'].quantile(0.25)
# Out:
# 73.75

# %%
df['Attendnce'].quantile(0.25)
# Out:
# 68.75

# %%
from pandas.plotting import scatter_matrix
pd.plotting.scatter_matrix(df,alpha=0.5,figsize=(6,6))
# Out:
# array([[<AxesSubplot:xlabel='Math', ylabel='Math'>,
#         <AxesSubplot:xlabel='Sci', ylabel='Math'>,
#         <AxesSubplot:xlabel='Eng', ylabel='Math'>,
#         <AxesSubplot:xlabel='Attendnce', ylabel='Math'>],
#        [<AxesSubplot:xlabel='Math', ylabel='Sci'>,
#         <AxesSubplot:xlabel='Sci', ylabel='Sci'>,
#         <AxesSubplot:xlabel='Eng', ylabel='Sci'>,
#         <AxesSubplot:xlabel='Attendnce', ylabel='Sci'>],
#        [<AxesSubplot:xlabel='Math', ylabel='Eng'>,
#         <AxesSubplot:xlabel='Sci', ylabel='Eng'>,
#         <AxesSubplot:xlabel='Eng', ylabel='Eng'>,
#         <AxesSubplot:xlabel='Attendnce', ylabel='Eng'>],
#        [<AxesSubplot:xlabel='Math', ylabel='Attendnce'>,
#         <AxesSubplot:xlabel='Sci', ylabel='Attendnce'>,
#         <AxesSubplot:xlabel='Eng', ylabel='Attendnce'>,
#         <AxesSubplot:xlabel='Attendnce', ylabel='Attendnce'>]],
#       dtype=object)
