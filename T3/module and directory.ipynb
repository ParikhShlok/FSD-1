# %% [markdown]
# # MODULES AND DIRECTORY

# %%
import os
dir(os)
# Out:
# ['DirEntry',
#  'F_OK',
#  'MutableMapping',
#  'O_APPEND',
#  'O_BINARY',
#  'O_CREAT',
#  'O_EXCL',
#  'O_NOINHERIT',
#  'O_RANDOM',
#  'O_RDONLY',
#  'O_RDWR',
#  'O_SEQUENTIAL',
#  'O_SHORT_LIVED',
#  'O_TEMPORARY',
#  'O_TEXT',
#  'O_TRUNC',
#  'O_WRONLY',
#  'P_DETACH',
#  'P_NOWAIT',
#  'P_NOWAITO',
#  'P_OVERLAY',
#  'P_WAIT',
#  'PathLike',
#  'R_OK',
#  'SEEK_CUR',
#  'SEEK_END',
#  'SEEK_SET',
#  'TMP_MAX',
#  'W_OK',
#  'X_OK',
#  '_AddedDllDirectory',
#  '_Environ',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_check_methods',
#  '_execvpe',
#  '_exists',
#  '_exit',
#  '_fspath',
#  '_get_exports_list',
#  '_putenv',
#  '_unsetenv',
#  '_wrap_close',
#  'abc',
#  'abort',
#  'access',
#  'add_dll_directory',
#  'altsep',
#  'chdir',
#  'chmod',
#  'close',
#  'closerange',
#  'cpu_count',
#  'curdir',
#  'defpath',
#  'device_encoding',
#  'devnull',
#  'dup',
# ...

# %%
pwd
# Out:
# 'C:\\Users\\LJENG\\T3'

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\LJENG\\T3'

# %%
os.chdir('C:\\Users\\LJENG\\T3')

# %%
pwd
# Out:
# 'C:\\Users\\LJENG\\T3'

# %%
os.chdir('C:\\Users\\LJENG')

# %%
pwd
# Out:
# 'C:\\Users\\LJENG'

# %%
os.chdir('C:\\Users\\LJENG\\T3')

# %%
pwd
# Out:
# 'C:\\Users\\LJENG\\T3'

# %%
os.mkdir('C:\\Users\\LJENG\\T3\\new')

# %%
os.rmdir('C:\\Users\\LJENG\\T3')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-22-90e396d4a020> in <module>
# ----> 1 os.rmdir('C:\\Users\\LJENG\\T3')
#
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\LJENG\\T3'

# %%
pwd
# Out:
# 'C:\\Users\\LJENG\\T3'

# %%
import os
os.rmdir('C:\\Users\\LJENG\\T3\\new')

# %%
#remove is used for file removing

# %% [markdown]
# ## MODULE

# %%
# %%writefile calc.py
def sum(a,b):
    print(a+b)
def sub(a,b):
    print(a-b)
def mul(a,b):
    print(a*b)
# Out:
# Writing calc.py

# %%
import calc
dir(calc)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'mul',
#  'sub',
#  'sum']

# %%
calc.sub(5,2)
# Out:
# 3

# %%
calc.sum(3,9)
# Out:
# 12

# %%
calc.mul(3,9)
# Out:
# 27

# %%
# %%writefile module.py
def sum(a,b):
    print(a+b)
def sub(a,b):
    print(a-b)
def mul(a,b):
    print(a*b)
def div(a,b):
    print(a/b)
# Out:
# Writing module.py

# %%
import module
dir(module)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'div',
#  'mul',
#  'sub',
#  'sum']

# %%
module.sub(50,30)
# Out:
# 20

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\LJENG\\T3'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'abc.txt',
#  'abc1.txt',
#  'abc2.txt',
#  'calc.py',
#  'compare1.txt',
#  'compare2.txt',
#  'count.txt',
#  'friend.txt',
#  'hello.txt',
#  'i1.txt',
#  'module and directory.ipynb',
#  'module.py',
#  'o1.text',
#  'o2.txt',
#  'odd.txt',
#  'output.txt',
#  'pager.txt',
#  'replace.txt',
#  'subject.txt',
#  'Working with File.ipynb',
#  'xyz.txt',
#  '__pycache__']

# %%
# %%writefile fun.py
import string
def flow(s):
    print(f"length={len(s)}")
    print(f"length={s.upper()}")
    print(f"length={s.lower()}")
    print(f"length={s.capitalize()}")
    print(f"length={s.isupper()}")
    print(f"length={s.islower()}")
# Out:
# Overwriting fun.py

# %%
import fun
import string
s=input("enter string")
fun.flow(s)
# Out:
# enter stringshlok
# length=5
# length=<built-in method upper of str object at 0x0000029DD91A4A30>
# length=<built-in method lower of str object at 0x0000029DD91A4A30>
# length=<built-in method capitalize of str object at 0x0000029DD91A4A30>
# length=False
# length=True

# %%
from datetime import *
print(date.today())
d=date(2002,8,6)
print(d)
# Out:
# 2025-12-03
# 2002-08-06

# %%
now=datetime.now()
print(now)
# Out:
# 2025-12-03 09:40:47.399751

# %% [markdown]
# ## Package and Sub-Package

# %%
pwd
# Out:
# 'C:\\Users\\LJENG\\T3'

# %%
import os
os.mkdir('C:\\Users\\LJENG\\T3\\pack1')

# %%
os.chdir('C:\\Users\\LJENG\\T3\\pack1')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\LJENG\\T3\\pack1'

# %%
# %%writefile modp.py
def fun():
    print("hello")
class hey:
    pass
# Out:
# Writing modp.py

# %%
# %%writefile modp2.py
def bun():
    print("good morning")
class by:
    pass
# Out:
# Writing modp2.py

# %%
import pack1.modp as m
dir(m)
m.fun()
m.hey#class ma round bracket no ave
# Out:
# hello
# pack1.modp.hey
